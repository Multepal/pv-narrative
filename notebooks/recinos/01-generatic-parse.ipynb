# %% [markdown]
# # Recinos: Parse

# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns; sns.set_theme(style='white')
from great_tables import GT, style, loc, exibble

# %%
DOC = pd.read_csv("recinos-CHAP.csv").set_index(['parte', 'capit'])
DOC
